# %%
# !pip install plotly.express

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('transaction_anomalies_dataset.csv')

# %%
data.head()
# Out:
#   Transaction_ID  Transaction_Amount  Transaction_Volume  \
# 0            TX0         1024.835708                   3
# 1            TX1         1013.952065                   4
# 2            TX2          970.956093                   1
# 3            TX3         1040.822254                   2
# 4            TX4          998.777241                   1
#
#    Average_Transaction_Amount  Frequency_of_Transactions  \
# 0                  997.234714                         12
# 1                 1020.210306                          7
# 2                  989.496604                          5
# 3                  969.522480                         16
# 4                 1007.111026                          7
#
#    Time_Since_Last_Transaction Day_of_Week Time_of_Day  Age  Gender   Income  \
# 0                           29      Friday       06:00   36    Male  1436074
# 1                           22      Friday       01:00   41  Female   627069
# ...

# %%
data.isnull().sum()
# Out:
# Transaction_ID                 0
# Transaction_Amount             0
# Transaction_Volume             0
# Average_Transaction_Amount     0
# Frequency_of_Transactions      0
# Time_Since_Last_Transaction    0
# Day_of_Week                    0
# Time_of_Day                    0
# Age                            0
# Gender                         0
# Income                         0
# Account_Type                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Transaction_ID               1000 non-null   object
#  1   Transaction_Amount           1000 non-null   float64
#  2   Transaction_Volume           1000 non-null   int64
#  3   Average_Transaction_Amount   1000 non-null   float64
#  4   Frequency_of_Transactions    1000 non-null   int64
#  5   Time_Since_Last_Transaction  1000 non-null   int64
#  6   Day_of_Week                  1000 non-null   object
#  7   Time_of_Day                  1000 non-null   object
#  8   Age                          1000 non-null   int64
#  9   Gender                       1000 non-null   object
#  10  Income                       1000 non-null   int64
#  11  Account_Type                 1000 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 93.9+ KB

# %%
data.describe()
# Out:
#        Transaction_Amount  Transaction_Volume  Average_Transaction_Amount  \
# count         1000.000000         1000.000000                 1000.000000
# mean          1038.122511            2.498000                 1000.682506
# std            283.580055            1.115006                   20.632334
# min            849.024392            1.000000                  939.081423
# 25%            966.028796            1.000000                  986.800556
# 50%           1002.118678            3.000000                 1000.501902
# 75%           1033.143657            3.000000                 1015.155595
# max           3227.459108            4.000000                 1073.154036
#
#        Frequency_of_Transactions  Time_Since_Last_Transaction          Age  \
# count                1000.000000                  1000.000000  1000.000000
# mean                   12.078000                    15.341000    40.641000
# std                     4.245225                     8.361258    13.819953
# ...

# %%
TransactionAmount_count = data['Transaction_Amount'].value_counts()
TransactionAmount_count
# Out:
# 1024.835708    1
# 962.362233     1
# 1030.486678    1
# 1053.418967    1
# 1053.224138    1
#               ..
# 1010.336202    1
# 1002.917550    1
# 1133.905494    1
# 1052.397103    1
# 968.289340     1
# Name: Transaction_Amount, Length: 1000, dtype: int64

# %%
fig_amount = px.histogram(data, x='Transaction_Amount',
                          nbins=20,
                          title='Distribution of Transaction Amount')

# %%
fig_amount.show()
# Out:
# <div>                            <div id="3e7d82fc-104d-4fdf-acb6-6da896f975a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e7d82fc-104d-4fdf-acb6-6da896f975a3")) {                    Plotly.newPlot(                        "3e7d82fc-104d-4fdf-acb6-6da896f975a3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Transaction_Amount=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[1024.8357076505615,1013.9520646100068,970.9560932988244,1040.8222540475665,998.7772411252968,969.9873074947044,973.3175598078756,931.103034808876,1036.9233289997703,1013.1
# ...

# %%
AccountType_count = data['Account_Type'].value_counts()

# %%
AccountType_count
# Out:
# Current    516
# Savings    484
# Name: Account_Type, dtype: int64

# %%
labels = ['Current', 'Savings']
sizes = [516, 484]

# %%
fig_box_amount = px.box(data,
                       x='Account_Type',
                       y='Transaction_Amount',
                       title='Transaction Amount by Account Type')

# %%
fig_box_amount.show()
# Out:
# <div>                            <div id="dc17a95a-e5b6-4abd-95d6-ccb97726c658" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc17a95a-e5b6-4abd-95d6-ccb97726c658")) {                    Plotly.newPlot(                        "dc17a95a-e5b6-4abd-95d6-ccb97726c658",                        [{"alignmentgroup":"True","hovertemplate":"Account_Type=%{x}\u003cbr\u003eTransaction_Amount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Savings","Savings","Savings","Savings","Savings","Savings","Savings","Savings","Savings","Current","Savings","Current","Savings","Current","Savings","Savings","Current","Savings","Savings","Savings
# ...
